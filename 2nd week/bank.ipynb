# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=str(input("Greeting: ")).lower()
a=''.join(i for i in a if i.isalpha() or i.isspace()).split(" ")
a=[i for i in a if i.isalpha()]
a


if a[0]=="hello":
    print("$0")
    
elif a[0].startswith("h"):
    print("$20")
else:
    print("$100")
# Out:
# $100

# %%
a="What's up?".lower()
a=''.join(i for i in a if i.isalpha() or i.isspace()).split(" ")
a=[i for i in a if i.isalpha()]
a
# Out:
# ['whats', 'up']

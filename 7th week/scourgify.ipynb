# %%
import os
import sys
import pandas as pd
import numpy as np

if (temp:= len(sys.argv)) <= 2:
    sys.exit("Too few command-line arguments")
elif temp >3:
    sys.exit("Too many command-line arguments")
path=sys.argv[1]
target=sys.argv[2]

try:
    df=pd.read_csv(path)
except:
    sys.exit(f'Could not read {path}')
    
first=[]
last=[]
for i in df["name"].to_numpy():
    temp = i.split(", ")
    first.append(temp[1])
    last.append(temp[0])
    
pd.DataFrame(list(zip(first, last, df["house"].to_numpy())), columns=["first", "last", "house"]).to_csv(target, index=False)
# Out:
#                        name       house
# 0            Abbott, Hannah  Hufflepuff
# 1               Bell, Katie  Gryffindor
# 2              Bones, Susan  Hufflepuff
# 3               Boot, Terry   Ravenclaw
# 4           Brown, Lavender  Gryffindor
# 5      Bulstrode, Millicent   Slytherin
# 6                Chang, Cho   Ravenclaw
# 7      Clearwater, Penelope   Ravenclaw
# 8           Crabbe, Vincent   Slytherin
# 9            Creevey, Colin  Gryffindor
# 10          Creevey, Dennis  Gryffindor
# 11          Diggory, Cedric  Hufflepuff
# 12      Edgecombe, Marietta   Ravenclaw
# 13  Finch-Fletchley, Justin  Hufflepuff
# 14         Finnigan, Seamus  Gryffindor
# 15       Goldstein, Anthony   Ravenclaw
# 16           Goyle, Gregory   Slytherin
# 17        Granger, Hermione  Gryffindor
# 18        Johnson, Angelina  Gryffindor
# 19              Jordan, Lee  Gryffindor
# 20      Longbottom, Neville  Gryffindor
# 21           Lovegood, Luna   Ravenclaw
# 22             Lupin, Remus  Gryffindor
# 23            Malfoy, Draco   Slytherin
# 24         Malfoy, Scorpius   Slytherin
# 25         Macmillan, Ernie  Hufflepuff
# 26      McGonagall, Minerva  Gryffindor
# 27           Midgen, Eloise  Gryffindor
# 28         McLaggen, Cormac  Gryffindor
# 29         Montague, Graham   Slytherin
# 30           Nott, Theodore   Slytherin
# 31         Parkinson, Pansy   Slytherin
# 32             Patil, Padma  Gryffindor
# 33           Patil, Parvati  Gryffindor
# 34            Potter, Harry  Gryffindor
# 35              Riddle, Tom   Slytherin
# 36          Robins, Demelza  Gryffindor
# 37          Scamander, Newt  Hufflepuff
# 38         Slughorn, Horace   Slytherin
# 39         Smith, Zacharias  Hufflepuff
# 40           Snape, Severus   Slytherin
# 41          Spinnet, Alicia  Gryffindor
# 42           Sprout, Pomona  Hufflepuff
# 43             Thomas, Dean  Gryffindor
# 44            Vane, Romilda  Gryffindor
# 45           Warren, Myrtle   Ravenclaw
# 46            Weasley, Fred  Gryffindor
# 47          Weasley, George  Gryffindor
# 48           Weasley, Ginny  Gryffindor
# 49           Weasley, Percy  Gryffindor
# 50             Weasley, Ron  Gryffindor
# 51             Wood, Oliver  Gryffindor
# 52           Zabini, Blaise   Slytherin
